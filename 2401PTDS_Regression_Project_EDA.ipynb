# %%
import pandas                as pd 
import numpy                 as np
import matplotlib.pyplot     as plt
import seaborn               as sns
import ipywidgets as widgets
from ipywidgets import interact
import statsmodels.graphics.correlation as sgc

# %%
df = pd.read_csv("C:/Users/Marcus/Data Science Course/Course Content/Regression/Project/co2_emissions_from_agri.csv")
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# The Exploratory Data Analysis (EDA) section is a critical phase in any data-driven project. This section will include various analyzing and visualizing techniques on the Avocado Sales dataset to uncover patterns, detect anomalies, and test hypotheses. In this section, we will use Python’s powerful libraries such as Pandas, Matplotlib, and Seaborn to examine the structure of the data, identify key trends, and gain insights that will guide the next steps in the analysis. The goal is to establish a clear understanding of the data, its quality, and its underlying relationships. Please note that the EDA section is conducted after the data was cleaned as explained in Section 4.

# %% [markdown]
# ### 5.1.Non-graphical EDA

# %% [markdown]
# In the Non-Graphical Exploratory Data Analysis (EDA) sub-section, we focus on gaining insights into the dataset using summary statistics and data manipulation techniques, without relying on visualizations. This approach involves examining key metrics such as mean, median, variance, and distribution of values across features, as well as identifying missing values and outliers. Using Python libraries like Pandas, we will explore the data through descriptive statistics, correlations, and data type checks, which will help to uncover hidden patterns and assess the overall structure of the dataset

# %%
df.head()
# Out:
#           Area  Year  Savanna fires  Forest fires  Crop Residues  \
# 0  Afghanistan  1990        14.7237        0.0557       205.6077
# 1  Afghanistan  1991        14.7237        0.0557       209.4971
# 2  Afghanistan  1992        14.7237        0.0557       196.5341
# 3  Afghanistan  1993        14.7237        0.0557       230.8175
# 4  Afghanistan  1994        14.7237        0.0557       242.0494
#
#    Rice Cultivation  Drained organic soils (CO2)  Pesticides Manufacturing  \
# 0            686.00                          0.0                 11.807483
# 1            678.16                          0.0                 11.712073
# 2            686.00                          0.0                 11.712073
# 3            686.00                          0.0                 11.712073
# 4            705.60                          0.0                 11.712073
#
#    Food Transport  Forestland  ...  Manure Management  Fires in organic soils  \
# ...

# %% [markdown]
# Looking at the top five rows of our data we can see all our features as well as the types of data we are working with.
#
# Our features are:
# - Area
# - Year
# - Savanna fires
# - Forest fires
# - Crop Residues
# - Rice Cultivation
# - Drained organic soils (CO2)
# - Pesticides Manufacturing
# - Food Transport
# - Forestland
# - Manure Management
# - Fires in organic soils
# - Fires in humid tropical forests
# - On-farm energy use
# - Rural population
# - Urban population
# - Total Population - Male
# - Total Population - Female
# - total_emission
# - Average Temperature °C

# %% [markdown]
# #### 5.1.1. Understaning the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6965 entries, 0 to 6964
# Data columns (total 31 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Area                             6965 non-null   object
#  1   Year                             6965 non-null   int64
#  2   Savanna fires                    6934 non-null   float64
#  3   Forest fires                     6872 non-null   float64
#  4   Crop Residues                    5576 non-null   float64
#  5   Rice Cultivation                 6965 non-null   float64
#  6   Drained organic soils (CO2)      6965 non-null   float64
#  7   Pesticides Manufacturing         6965 non-null   float64
#  8   Food Transport                   6965 non-null   float64
#  9   Forestland                       6472 non-null   float64
#  10  Net Forest conversion            6472 non-null   float64
# ...

# %%
df.shape
# Out:
# (6965, 31)

# %%
df.isnull().sum()
# Out:
# Area                                  0
# Year                                  0
# Savanna fires                        31
# Forest fires                         93
# Crop Residues                      1389
# Rice Cultivation                      0
# Drained organic soils (CO2)           0
# Pesticides Manufacturing              0
# Food Transport                        0
# Forestland                          493
# Net Forest conversion               493
# Food Household Consumption          473
# Food Retail                           0
# On-farm Electricity Use               0
# Food Packaging                        0
# Agrifood Systems Waste Disposal       0
# Food Processing                       0
# Fertilizers Manufacturing             0
# IPPU                                743
# Manure applied to Soils             928
# Manure left on Pasture                0
# Manure Management                   928
# Fires in organic soils                0
# ...

# %% [markdown]
# #### 5.1.2. Data Statistics overview

# %%
df.describe()
# Out:
#               Year  Savanna fires  Forest fires  Crop Residues  \
# count  6965.000000    6934.000000   6872.000000    5576.000000
# mean   2005.124910    1188.390893    919.302167     998.706309
# std       8.894665    5246.287783   3720.078752    3700.345330
# min    1990.000000       0.000000      0.000000       0.000200
# 25%    1997.000000       0.000000      0.000000      11.006525
# 50%    2005.000000       1.651850      0.517900     103.698200
# 75%    2013.000000     111.081400     64.950775     377.640975
# max    2020.000000  114616.401100  52227.630600   33490.074100
#
#        Rice Cultivation  Drained organic soils (CO2)  \
# count       6965.000000                  6965.000000
# mean        4259.666673                  3503.228636
# std        17613.825187                 15861.445678
# min            0.000000                     0.000000
# 25%          181.260800                     0.000000
# 50%          534.817400                     0.000000
# ...

# %% [markdown]
# Descriptive statistics overview of each column to see if we can spot any anomalies.

# %% [markdown]
# #### 5.1.3. Central tendency

# %%
mode = df.mode(numeric_only=True)
first_index_mode = mode.iloc[0]

print(first_index_mode)
# Out:
# Year                               2.006000e+03
# Savanna fires                      0.000000e+00
# Forest fires                       0.000000e+00
# Crop Residues                      2.000000e-04
# Rice Cultivation                   2.464073e+02
# Drained organic soils (CO2)        0.000000e+00
# Pesticides Manufacturing           1.148108e+01
# Food Transport                     2.626266e+01
# Forestland                         0.000000e+00
# Net Forest conversion              0.000000e+00
# Food Household Consumption         5.104000e-01
# Food Retail                        3.783863e+01
# On-farm Electricity Use            1.700466e+01
# Food Packaging                     6.763137e+01
# Agrifood Systems Waste Disposal    6.507235e+01
# Food Processing                    2.095877e+02
# Fertilizers Manufacturing          3.564910e+02
# IPPU                               0.000000e+00
# Manure applied to Soils            4.900000e-02
# Manure left on Pasture             2.148252e+03
# ...

# %% [markdown]
# #####  5.1.3.1. Mode

# %%
mode = df.mode(numeric_only=True)
first_index_mode = mode.iloc[0]

print(first_index_mode)
# Out:
# Year                               2.006000e+03
# Savanna fires                      0.000000e+00
# Forest fires                       0.000000e+00
# Crop Residues                      2.000000e-04
# Rice Cultivation                   2.464073e+02
# Drained organic soils (CO2)        0.000000e+00
# Pesticides Manufacturing           1.148108e+01
# Food Transport                     2.626266e+01
# Forestland                         0.000000e+00
# Net Forest conversion              0.000000e+00
# Food Household Consumption         5.104000e-01
# Food Retail                        3.783863e+01
# On-farm Electricity Use            1.700466e+01
# Food Packaging                     6.763137e+01
# Agrifood Systems Waste Disposal    6.507235e+01
# Food Processing                    2.095877e+02
# Fertilizers Manufacturing          3.564910e+02
# IPPU                               0.000000e+00
# Manure applied to Soils            4.900000e-02
# Manure left on Pasture             2.148252e+03
# ...

# %% [markdown]
# #####  5.1.3.2. Median

# %%
median_df = df[['Savanna fires', 'Forest fires','Crop Residues','Rice Cultivation','Drained organic soils (CO2)',
                'Pesticides Manufacturing','Food Transport','Forestland','Net Forest conversion',
                'Food Household Consumption','Food Retail','On-farm Electricity Use','Food Packaging',
                'Fertilizers Manufacturing','IPPU','Manure applied to Soils','Manure left on Pasture',
                'Manure Management','Fires in organic soils','Fires in humid tropical forests','On-farm energy use',
                'Rural population','Urban population','Total Population - Male','Total Population - Female',
                'total_emission','Average Temperature °C']].median()
print(median_df)
# Out:
# Savanna fires                      1.651850e+00
# Forest fires                       5.179000e-01
# Crop Residues                      1.036982e+02
# Rice Cultivation                   5.348174e+02
# Drained organic soils (CO2)        0.000000e+00
# Pesticides Manufacturing           1.300000e+01
# Food Transport                     2.049628e+02
# Forestland                        -6.292000e+01
# Net Forest conversion              4.444000e+01
# Food Household Consumption         1.554711e+02
# Food Retail                        1.720426e+02
# On-farm Electricity Use            2.912070e+01
# Food Packaging                     7.401813e+01
# Fertilizers Manufacturing          1.115052e+03
# IPPU                               8.037066e+02
# Manure applied to Soils            1.204439e+02
# Manure left on Pasture             9.725674e+02
# Manure Management                  2.698563e+02
# Fires in organic soils             0.000000e+00
# Fires in humid tropical forests    0.000000e+00
# ...

# %% [markdown]
# #####  5.1.3.3. Mean

# %%
mean_df = df[['Savanna fires', 'Forest fires','Crop Residues','Rice Cultivation','Drained organic soils (CO2)',
                'Pesticides Manufacturing','Food Transport','Forestland','Net Forest conversion',
                'Food Household Consumption','Food Retail','On-farm Electricity Use','Food Packaging',
                'Fertilizers Manufacturing','IPPU','Manure applied to Soils','Manure left on Pasture',
                'Manure Management','Fires in organic soils','Fires in humid tropical forests','On-farm energy use',
                'Rural population','Urban population','Total Population - Male','Total Population - Female',
                'total_emission','Average Temperature °C']].mean()
print(mean_df)
# Out:
# Savanna fires                      1.188391e+03
# Forest fires                       9.193022e+02
# Crop Residues                      9.987063e+02
# Rice Cultivation                   4.259667e+03
# Drained organic soils (CO2)        3.503229e+03
# Pesticides Manufacturing           3.334184e+02
# Food Transport                     1.939582e+03
# Forestland                        -1.782829e+04
# Net Forest conversion              1.760564e+04
# Food Household Consumption         4.847580e+03
# Food Retail                        2.043211e+03
# On-farm Electricity Use            1.626681e+03
# Food Packaging                     1.658630e+03
# Fertilizers Manufacturing          3.035723e+03
# IPPU                               1.999150e+04
# Manure applied to Soils            9.232256e+02
# Manure left on Pasture             3.518027e+03
# Manure Management                  2.263345e+03
# Fires in organic soils             1.210316e+03
# Fires in humid tropical forests    6.684529e+02
# ...

# %% [markdown]
# #### 5.1.4. Skewness & Kurtosis

# %%
Sk_K_df = df.drop(columns=['Year'])

# %%
Sk_K_df.skew(numeric_only=True)
# Out:
# Savanna fires                      10.347117
# Forest fires                        5.839271
# Crop Residues                       6.105082
# Rice Cultivation                    6.896294
# Drained organic soils (CO2)        10.500934
# Pesticides Manufacturing            7.405085
# Food Transport                      6.116029
# Forestland                         -6.307422
# Net Forest conversion              11.771650
# Food Household Consumption         11.356973
# Food Retail                         9.309412
# On-farm Electricity Use             9.750162
# Food Packaging                     11.979253
# Agrifood Systems Waste Disposal     6.953953
# Food Processing                     9.364626
# Fertilizers Manufacturing          10.255483
# IPPU                               11.243412
# Manure applied to Soils             6.577909
# Manure left on Pasture              5.495126
# Manure Management                   6.336033
# Fires in organic soils             26.357767
# ...

# %% [markdown]
# The data presents the skewness values for various factors influencing emissions. Positive skewness values indicate that the distribution of most factors is right-skewed, with a long tail to the right. Notably, "Fires in organic soils" (26.36), "Food Packaging" (11.98), and "Net Forest Conversion" (11.77) exhibit the highest skewness, suggesting that these activities have a disproportionate impact on emissions, with a few extreme values driving the distribution. On the other hand, factors like "Average Temperature" (0.33) and "Total Population - Female" (7.80) show lower skewness, implying more balanced or less extreme distributions in their emission contributions. This highlights the prominence of certain environmental factors and industries in influencing emission patterns.

# %%
Sk_K_df.kurtosis(numeric_only=True)
# Out:
# Savanna fires                      157.123473
# Forest fires                        38.862255
# Crop Residues                       39.239780
# Rice Cultivation                    50.375853
# Drained organic soils (CO2)        131.538354
# Pesticides Manufacturing            59.773128
# Food Transport                      48.794946
# Forestland                          43.487068
# Net Forest conversion              157.780226
# Food Household Consumption         152.413754
# Food Retail                        103.279139
# On-farm Electricity Use            112.460201
# Food Packaging                     155.498327
# Agrifood Systems Waste Disposal     52.912176
# Food Processing                     99.118839
# Fertilizers Manufacturing          116.215306
# IPPU                               144.234525
# Manure applied to Soils             48.334425
# Manure left on Pasture              35.322616
# Manure Management                   42.666018
# ...

# %% [markdown]
# The kurtosis values indicate that most factors have heavy-tailed distributions, with extreme values significantly influencing the data. "Fires in organic soils" (838.52), "Food Packaging" (155.50), and "Net Forest Conversion" (157.78) show the highest kurtosis, suggesting a concentration of extreme emissions in these areas. In contrast, factors like "Average Temperature" (1.03) have low kurtosis, indicating more stable and less extreme distributions. Overall, the data suggests that activities related to land use and food systems exhibit more extreme emission events than demographic factors.

# %% [markdown]
# #### 5.1.5. Non-Numeric Data

# %%
df.select_dtypes(include=['object']).head()
# Out:
#           Area
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
df.groupby('Area')[['Average Temperature °C']].sum().sort_values(by='Average Temperature °C', ascending=False).head(10)
# Out:
#                     Average Temperature °C
# Area
# Finland                          45.017083
# Estonia                          44.152250
# Mongolia                         43.542667
# Belarus                          43.376000
# Austria                          43.187500
# Latvia                           43.053667
# Russian Federation               43.024250
# Sweden                           42.394000
# Mauritania                       41.910667
# Liechtenstein                    41.833500

# %%
grouped_df = df.groupby(['Year', 'Area']).agg({'Average Temperature °C': 'sum'}).reset_index()
print(grouped_df)
# Out:
#       Year                       Area  Average Temperature °C
# 0     1990                Afghanistan                0.536167
# 1     1990                    Albania                0.735750
# 2     1990                    Algeria                1.005583
# 3     1990             American Samoa                0.566500
# 4     1990                    Andorra                1.278500
# ...    ...                        ...                     ...
# 6960  2020  Wallis and Futuna Islands                1.232333
# 6961  2020             Western Sahara                2.068000
# 6962  2020                      Yemen                1.320126
# 6963  2020                     Zambia                0.714417
# 6964  2020                   Zimbabwe                0.189000
#
# [6965 rows x 3 columns]

# %% [markdown]
# ## 5.2. Graphical EDA

# %% [markdown]
# The Graphical Exploratory Data Analysis (EDA) sub-section involves visualizing data to uncover patterns, trends, and relationships that are not immediately apparent from statistical summaries alone. By employing various plotting techniques, such as histograms, scatter plots, box plots, and heatmaps, we can visually explore the distribution of individual variables, compare different groups, and identify correlations and anomalies. This visual approach enhances our understanding of the dataset and helps in detecting underlying structures and trends that may inform further analysis.

# %% [markdown]
# #### 5.2.1. Histogram

# %%
features = ['Savanna fires', 'Forest fires','Crop Residues','Rice Cultivation','Drained organic soils (CO2)',
                'Pesticides Manufacturing','Food Transport','Forestland','Net Forest conversion',
                'Food Household Consumption','Food Retail','On-farm Electricity Use','Food Packaging',
                'Fertilizers Manufacturing','IPPU','Manure applied to Soils','Manure left on Pasture',
                'Manure Management','Fires in organic soils','Fires in humid tropical forests','On-farm energy use',
                'Rural population','Urban population','Total Population - Male','Total Population - Female',
                'total_emission','Average Temperature °C']
df[features].hist(figsize=(20,20));
plt.savefig('Histogram_image.png', bbox_inches='tight')  # Save as PNG file

# %% [markdown]
# #### 5.2.1. Box Plot

# %%
features = ['Savanna fires', 'Forest fires', 'Crop Residues', 'Rice Cultivation', 'Drained organic soils (CO2)',
            'Pesticides Manufacturing', 'Food Transport', 'Forestland', 'Net Forest conversion',
            'Food Household Consumption', 'Food Retail', 'On-farm Electricity Use', 'Food Packaging',
            'Fertilizers Manufacturing', 'IPPU', 'Manure applied to Soils', 'Manure left on Pasture',
            'Manure Management', 'Fires in organic soils', 'Fires in humid tropical forests', 'On-farm energy use',
            'Rural population', 'Urban population', 'Total Population - Male', 'Total Population - Female',
            'total_emission', 'Average Temperature °C']

# Prompt user to select a feature
print("Please choose a feature number from the following list, Example 1:")
for i, feature in enumerate(features, 1):
    print(f"{i}. {feature}")
    
# Input selection (you can validate the input in a more advanced way, here assuming user input is valid)
selection = int(input("\nEnter the number corresponding to the feature you want to plot: ")) - 1
selected_feature = features[selection]

# Create the box plot
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x=selected_feature)

# Customize the plot
plt.title(f"Box plot of {selected_feature}")
plt.xlabel(selected_feature)
plt.ylabel("Value")
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# Please choose a feature number from the following list, Example 1:
# 1. Savanna fires
# 2. Forest fires
# 3. Crop Residues
# 4. Rice Cultivation
# 5. Drained organic soils (CO2)
# 6. Pesticides Manufacturing
# 7. Food Transport
# 8. Forestland
# 9. Net Forest conversion
# 10. Food Household Consumption
# 11. Food Retail
# 12. On-farm Electricity Use
# 13. Food Packaging
# 14. Fertilizers Manufacturing
# 15. IPPU
# 16. Manure applied to Soils
# 17. Manure left on Pasture
# 18. Manure Management
# 19. Fires in organic soils
# 20. Fires in humid tropical forests
# 21. On-farm energy use
# 22. Rural population
# 23. Urban population
# 24. Total Population - Male
# 25. Total Population - Female
# 26. total_emission
# 27. Average Temperature °C
# Enter the number corresponding to the feature you want to plot:  27

# %% [markdown]
# #### 5.2.2. Violin Plot

# %%
features = ['Savanna fires', 'Forest fires', 'Crop Residues', 'Rice Cultivation', 'Drained organic soils (CO2)',
            'Pesticides Manufacturing', 'Food Transport', 'Forestland', 'Net Forest conversion',
            'Food Household Consumption', 'Food Retail', 'On-farm Electricity Use', 'Food Packaging',
            'Fertilizers Manufacturing', 'IPPU', 'Manure applied to Soils', 'Manure left on Pasture',
            'Manure Management', 'Fires in organic soils', 'Fires in humid tropical forests', 'On-farm energy use',
            'Rural population', 'Urban population', 'Total Population - Male', 'Total Population - Female',
            'total_emission', 'Average Temperature °C']

# Prompt user to select a feature
print("Please choose a feature number from the following list, Example 1:")
for i, feature in enumerate(features, 1):
    print(f"{i}. {feature}")

selection = int(input("\nEnter the number corresponding to the feature you want to plot: ")) - 1
selected_feature = features[selection]

# Create the box plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=df, x=selected_feature)

# Customize the plot
plt.title(f"Box plot of {selected_feature}")
plt.xlabel(selected_feature)
plt.ylabel("Value")

# Show the plot
plt.show()
# Out:
# Please choose a feature number from the following list, Example 1:
# 1. Savanna fires
# 2. Forest fires
# 3. Crop Residues
# 4. Rice Cultivation
# 5. Drained organic soils (CO2)
# 6. Pesticides Manufacturing
# 7. Food Transport
# 8. Forestland
# 9. Net Forest conversion
# 10. Food Household Consumption
# 11. Food Retail
# 12. On-farm Electricity Use
# 13. Food Packaging
# 14. Fertilizers Manufacturing
# 15. IPPU
# 16. Manure applied to Soils
# 17. Manure left on Pasture
# 18. Manure Management
# 19. Fires in organic soils
# 20. Fires in humid tropical forests
# 21. On-farm energy use
# 22. Rural population
# 23. Urban population
# 24. Total Population - Male
# 25. Total Population - Female
# 26. total_emission
# 27. Average Temperature °C
# Enter the number corresponding to the feature you want to plot:  7

# %% [markdown]
# #### 5.2.3. Bar Graph

# %%
features = ['Savanna fires', 'Forest fires', 'Crop Residues', 'Rice Cultivation', 'Drained organic soils (CO2)',
            'Pesticides Manufacturing', 'Food Transport', 'Forestland', 'Net Forest conversion',
            'Food Household Consumption', 'Food Retail', 'On-farm Electricity Use', 'Food Packaging',
            'Fertilizers Manufacturing', 'IPPU', 'Manure applied to Soils', 'Manure left on Pasture',
            'Manure Management', 'Fires in organic soils', 'Fires in humid tropical forests', 'On-farm energy use',
            'Rural population', 'Urban population', 'Total Population - Male', 'Total Population - Female',
            'total_emission', 'Average Temperature °C']

# Prompt user to select a feature
print("Please choose a feature number from the following list, Example 1:")
for i, feature in enumerate(features, 1):
    print(f"{i}. {feature}")

selection = int(input("\nEnter the number corresponding to the feature you want to plot: ")) - 1
selected_feature = features[selection]

# Create the box plot
plt.figure(figsize=(16, 6))
sns.barplot(x='Year', y=selected_feature, data=df)
# Customize the plot
plt.title(f'Bar Graph of {selected_feature}')
plt.xlabel('Year')
plt.ylabel(selected_feature)
plt.savefig('Bar.png', bbox_inches='tight')  # Save as PNG file
# Show the plot
plt.show()
# Out:
# Please choose a feature number from the following list, Example 1:
# 1. Savanna fires
# 2. Forest fires
# 3. Crop Residues
# 4. Rice Cultivation
# 5. Drained organic soils (CO2)
# 6. Pesticides Manufacturing
# 7. Food Transport
# 8. Forestland
# 9. Net Forest conversion
# 10. Food Household Consumption
# 11. Food Retail
# 12. On-farm Electricity Use
# 13. Food Packaging
# 14. Fertilizers Manufacturing
# 15. IPPU
# 16. Manure applied to Soils
# 17. Manure left on Pasture
# 18. Manure Management
# 19. Fires in organic soils
# 20. Fires in humid tropical forests
# 21. On-farm energy use
# 22. Rural population
# 23. Urban population
# 24. Total Population - Male
# 25. Total Population - Female
# 26. total_emission
# 27. Average Temperature °C
# Enter the number corresponding to the feature you want to plot:  26

# %% [markdown]
# #### 5.2.4. Correlation

# %% [markdown]
# ##### Correlation is a measure of the degree to which two variables change together, if at all

# %%
New_df = df.drop(columns=['Year'])

# %%
correlation_matrix = New_df.corr(numeric_only=True)
print("\nCorrelation matrix of the variables:")
correlation_matrix
# Out:
# Correlation matrix of the variables:
#                                  Savanna fires  Forest fires  Crop Residues  \
# Savanna fires                         1.000000      0.507098       0.026309
# Forest fires                          0.507098      1.000000       0.075935
# Crop Residues                         0.026309      0.075935       1.000000
# Rice Cultivation                     -0.030414      0.070997       0.826125
# Drained organic soils (CO2)           0.016874      0.107947       0.208585
# Pesticides Manufacturing              0.060794      0.052947       0.875560
# Food Transport                        0.070335      0.071083       0.769346
# Forestland                           -0.058412     -0.150876      -0.737550
# Net Forest conversion                 0.226274      0.420323       0.119842
# Food Household Consumption            0.002361      0.019466       0.852631
# Food Retail                           0.015488      0.028518       0.832884
# ...

# %% [markdown]
# #### 5.2.5. Heatmap

# %% [markdown]
# ##### The relationship between features can also be displayed graphically using a heatmap

# %%
plt.figure(figsize=(20, 20))  # Adjust the figure size
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, 
            cbar_kws={"shrink": .8}, linewidths=.5)

# Rotate x and y tick labels
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.title('Correlation Heatmap of Variables')
plt.tight_layout()
plt.savefig('heatmap_image.png', bbox_inches='tight')  # Save as PNG file
plt.show()
